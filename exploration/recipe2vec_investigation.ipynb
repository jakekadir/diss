# %%
from recipe_rec import recipes, unique_ingredients
from recipe_rec.recipe2vec import Recipe2Vec
import itertools
import pickle

# %% [markdown]
# # Effect of Alpha and Num. Epochs on Loss Stabilisation

# %%
systems = {}

alphas = [0.025, 0.0025, 0.025]
epochs = [10, 100, 300]

losses = {}

for alpha, num_epochs in list(itertools.product(alphas, epochs)):
    systems["recipe2vec"] = Recipe2Vec(
        # model_path="./recipe_rec/data/recipe2vec_42d574c155524a28a8ae6ee691d96e85.model",
        alpha=alpha,
        num_epochs=num_epochs,
        # index_path="./recipe_rec/data/recipe2vec_7153b2f49949474495fd9ffe8b340baf.ann",
        verbose=False,
    )

    training_losses = systems["recipe2vec"].training_losses

    losses[(alpha, num_epochs)] = [1, 2, 3, 4]
# Out:
# INFO - 15:38:59: collecting all words and their counts
# INFO - 15:38:59: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 15:38:59: PROGRESS: at sentence #10000, processed 78783 words, keeping 3498 word types
# INFO - 15:38:59: PROGRESS: at sentence #20000, processed 156666 words, keeping 4106 word types
# INFO - 15:38:59: PROGRESS: at sentence #30000, processed 234118 words, keeping 4459 word types
# INFO - 15:38:59: PROGRESS: at sentence #40000, processed 312517 words, keeping 4694 word types
# INFO - 15:39:00: PROGRESS: at sentence #50000, processed 392108 words, keeping 4858 word types
# INFO - 15:39:00: PROGRESS: at sentence #60000, processed 471699 words, keeping 5007 word types
# INFO - 15:39:00: PROGRESS: at sentence #70000, processed 550299 words, keeping 5126 word types
# INFO - 15:39:00: PROGRESS: at sentence #80000, processed 631287 words, keeping 5227 word types
# INFO - 15:39:00: PROGRESS: at sentence #90000, processed 712934 words, keeping 5395 word types
# INFO - 15:39:00: PROGRESS: at sentence #100000, processed 793311 words, keeping 5573 word types
# INFO - 15:39:00: PROGRESS: at sentence #110000, processed 875780 words, keeping 5721 word types
# INFO - 15:39:00: PROGRESS: at sentence #120000, processed 953574 words, keeping 5787 word types
# INFO - 15:39:00: PROGRESS: at sentence #130000, processed 1034017 words, keeping 5842 word types
# INFO - 15:39:00: PROGRESS: at sentence #140000, processed 1115188 words, keeping 5906 word types
# INFO - 15:39:00: PROGRESS: at sentence #150000, processed 1193851 words, keeping 5967 word types
# INFO - 15:39:00: PROGRESS: at sentence #160000, processed 1273109 words, keeping 6032 word types
# INFO - 15:39:00: PROGRESS: at sentence #170000, processed 1351713 words, keeping 6073 word types
# INFO - 15:39:00: PROGRESS: at sentence #180000, processed 1432251 words, keeping 6126 word types
# INFO - 15:39:00: PROGRESS: at sentence #190000, processed 1513299 words, keeping 6169 word types
# INFO - 15:39:00: PROGRESS: at sentence #200000, processed 1594181 words, keeping 6212 word types
# INFO - 15:39:00: PROGRESS: at sentence #210000, processed 1673262 words, keeping 6262 word types
# INFO - 15:39:00: PROGRESS: at sentence #220000, processed 1753135 words, keeping 6310 word types
# INFO - 15:39:00: PROGRESS: at sentence #230000, processed 1831365 words, keeping 6358 word types
# INFO - 15:39:00: PROGRESS: at sentence #240000, processed 1909358 words, keeping 6390 word types
# INFO - 15:39:00: PROGRESS: at sentence #250000, processed 1988304 words, keeping 6433 word types
# INFO - 15:39:00: PROGRESS: at sentence #260000, processed 2066882 words, keeping 6464 word types
# INFO - 15:39:00: PROGRESS: at sentence #270000, processed 2146775 words, keeping 6495 word types
# INFO - 15:39:00: PROGRESS: at sentence #280000, processed 2225474 words, keeping 6523 word types
# INFO - 15:39:00: PROGRESS: at sentence #290000, processed 2302840 words, keeping 6554 word types
# INFO - 15:39:00: PROGRESS: at sentence #300000, processed 2381100 words, keeping 6583 word types
# INFO - 15:39:00: PROGRESS: at sentence #310000, processed 2459562 words, keeping 6612 word types
# INFO - 15:39:00: PROGRESS: at sentence #320000, processed 2540749 words, keeping 6646 word types
# INFO - 15:39:00: PROGRESS: at sentence #330000, processed 2620439 words, keeping 6670 word types
# INFO - 15:39:00: PROGRESS: at sentence #340000, processed 2701943 words, keeping 6703 word types
# INFO - 15:39:00: PROGRESS: at sentence #350000, processed 2782900 words, keeping 6733 word types
# INFO - 15:39:00: PROGRESS: at sentence #360000, processed 2863945 words, keeping 6791 word types
# INFO - 15:39:00: PROGRESS: at sentence #370000, processed 2945972 words, keeping 6827 word types
# INFO - 15:39:00: PROGRESS: at sentence #380000, processed 3027762 words, keeping 6857 word types
# INFO - 15:39:00: PROGRESS: at sentence #390000, processed 3110306 words, keeping 6899 word types
# INFO - 15:39:00: PROGRESS: at sentence #400000, processed 3192242 words, keeping 6939 word types
# INFO - 15:39:00: PROGRESS: at sentence #410000, processed 3272235 words, keeping 6977 word types
# INFO - 15:39:01: PROGRESS: at sentence #420000, processed 3356013 words, keeping 7007 word types
# INFO - 15:39:01: PROGRESS: at sentence #430000, processed 3437614 words, keeping 7036 word types
# INFO - 15:39:01: PROGRESS: at sentence #440000, processed 3518441 words, keeping 7071 word types
# INFO - 15:39:01: PROGRESS: at sentence #450000, processed 3602971 words, keeping 7114 word types
# INFO - 15:39:01: PROGRESS: at sentence #460000, processed 3686573 words, keeping 7179 word types
# INFO - 15:39:01: PROGRESS: at sentence #470000, processed 3770651 words, keeping 7216 word types
# INFO - 15:39:01: PROGRESS: at sentence #480000, processed 3855474 words, keeping 7256 word types
# INFO - 15:39:01: PROGRESS: at sentence #490000, processed 3936148 words, keeping 7296 word types
# INFO - 15:39:01: PROGRESS: at sentence #500000, processed 4018371 words, keeping 7305 word types
# INFO - 15:39:01: PROGRESS: at sentence #510000, processed 4106690 words, keeping 7358 word types
# INFO - 15:39:01: collected 7358 word types from a corpus of 4120761 raw words and 511626 sentences
# INFO - 15:39:01: Creating a fresh vocabulary
# INFO - 15:39:01: Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 7358 unique words (100.00% of original 7358, drops 0)', 'datetime': '2023-04-22T15:39:01.307726', 'gensim': '4.3.1', 'python': '3.8.3 (default, Jul  2 2020, 16:21:59) \n[GCC 7.3.0]', 'platform': 'Linux-5.15.0-69-generic-x86_64-with-glibc2.10', 'event': 'prepare_vocab'}
# INFO - 15:39:01: Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 4120761 word corpus (100.00% of original 4120761, drops 0)', 'datetime': '2023-04-22T15:39:01.308595', 'gensim': '4.3.1', 'python': '3.8.3 (default, Jul  2 2020, 16:21:59) \n[GCC 7.3.0]', 'platform': 'Linux-5.15.0-69-generic-x86_64-with-glibc2.10', 'event': 'prepare_vocab'}
# INFO - 15:39:01: deleting the raw counts dictionary of 7358 items
# INFO - 15:39:01: sample=0.001 downsamples 67 most-common words
# INFO - 15:39:01: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 2922964.5935400887 word corpus (70.9%% of prior 4120761)', 'datetime': '2023-04-22T15:39:01.371366', 'gensim': '4.3.1', 'python': '3.8.3 (default, Jul  2 2020, 16:21:59) \n[GCC 7.3.0]', 'platform': 'Linux-5.15.0-69-generic-x86_64-with-glibc2.10', 'event': 'prepare_vocab'}
# INFO - 15:39:01: estimated required memory for 7358 words and 100 dimensions: 9565400 bytes
# INFO - 15:39:01: resetting layer weights
# INFO - 15:39:01: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-04-22T15:39:01.449778', 'gensim': '4.3.1', 'python': '3.8.3 (default, Jul  2 2020, 16:21:59) \n[GCC 7.3.0]', 'platform': 'Linux-5.15.0-69-generic-x86_64-with-glibc2.10', 'event': 'build_vocab'}
# INFO - 15:39:01: Word2Vec lifecycle event {'msg': 'training model with 3 workers on 7358 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2023-04-22T15:39:01.451227', 'gensim': '4.3.1', 'python': '3.8.3 (default, Jul  2 2020, 16:21:59) \n[GCC 7.3.0]', 'platform': 'Linux-5.15.0-69-generic-x86_64-with-glibc2.10', 'event': 'train'}
# INFO - 15:39:02: EPOCH 0 - PROGRESS: at 23.35% examples, 658161 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:03: EPOCH 0 - PROGRESS: at 46.66% examples, 661370 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:04: EPOCH 0 - PROGRESS: at 70.48% examples, 667029 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:05: EPOCH 0 - PROGRESS: at 92.95% examples, 669276 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:05: EPOCH 0: training on 4120761 raw words (2924417 effective words) took 4.3s, 672450 effective words/s
# INFO - 15:39:06: EPOCH 1 - PROGRESS: at 23.85% examples, 674101 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:07: EPOCH 1 - PROGRESS: at 45.66% examples, 649120 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:08: EPOCH 1 - PROGRESS: at 66.38% examples, 631048 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:09: EPOCH 1 - PROGRESS: at 87.61% examples, 629705 words/s, in_qsize 4, out_qsize 1
# INFO - 15:39:10: EPOCH 1: training on 4120761 raw words (2923117 effective words) took 4.6s, 637094 effective words/s
# INFO - 15:39:11: EPOCH 2 - PROGRESS: at 21.59% examples, 607533 words/s, in_qsize 6, out_qsize 0
# INFO - 15:39:12: EPOCH 2 - PROGRESS: at 44.41% examples, 631039 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:13: EPOCH 2 - PROGRESS: at 65.89% examples, 626440 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:14: EPOCH 2 - PROGRESS: at 86.00% examples, 618750 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:15: EPOCH 2: training on 4120761 raw words (2922561 effective words) took 4.8s, 614726 effective words/s
# INFO - 15:39:16: EPOCH 3 - PROGRESS: at 22.09% examples, 619734 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:17: EPOCH 3 - PROGRESS: at 46.41% examples, 659192 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:18: EPOCH 3 - PROGRESS: at 69.51% examples, 658666 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:19: EPOCH 3 - PROGRESS: at 91.31% examples, 656542 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:19: EPOCH 3: training on 4120761 raw words (2923118 effective words) took 4.4s, 659881 effective words/s
# INFO - 15:39:20: EPOCH 4 - PROGRESS: at 24.09% examples, 673076 words/s, in_qsize 6, out_qsize 0
# INFO - 15:39:21: EPOCH 4 - PROGRESS: at 48.39% examples, 678389 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:22: EPOCH 4 - PROGRESS: at 70.96% examples, 670569 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:23: EPOCH 4 - PROGRESS: at 90.85% examples, 652810 words/s, in_qsize 6, out_qsize 0
# INFO - 15:39:24: EPOCH 4: training on 4120761 raw words (2923230 effective words) took 4.6s, 641224 effective words/s
# INFO - 15:39:25: EPOCH 5 - PROGRESS: at 20.66% examples, 579124 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:26: EPOCH 5 - PROGRESS: at 41.19% examples, 584200 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:27: EPOCH 5 - PROGRESS: at 64.93% examples, 616605 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:28: EPOCH 5 - PROGRESS: at 88.56% examples, 638444 words/s, in_qsize 6, out_qsize 0
# INFO - 15:39:28: EPOCH 5: training on 4120761 raw words (2922249 effective words) took 4.5s, 645449 effective words/s
# INFO - 15:39:29: EPOCH 6 - PROGRESS: at 24.33% examples, 688434 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:30: EPOCH 6 - PROGRESS: at 49.63% examples, 707571 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:31: EPOCH 6 - PROGRESS: at 74.29% examples, 709337 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:32: EPOCH 6 - PROGRESS: at 97.72% examples, 706834 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:32: EPOCH 6: training on 4120761 raw words (2923569 effective words) took 4.1s, 706822 effective words/s
# INFO - 15:39:33: EPOCH 7 - PROGRESS: at 25.54% examples, 719579 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:34: EPOCH 7 - PROGRESS: at 49.13% examples, 698811 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:35: EPOCH 7 - PROGRESS: at 73.81% examples, 703441 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:36: EPOCH 7 - PROGRESS: at 97.01% examples, 702169 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:37: EPOCH 7: training on 4120761 raw words (2924785 effective words) took 4.2s, 702937 effective words/s
# INFO - 15:39:38: EPOCH 8 - PROGRESS: at 25.06% examples, 703095 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:39: EPOCH 8 - PROGRESS: at 50.13% examples, 710976 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:40: EPOCH 8 - PROGRESS: at 74.53% examples, 708285 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:41: EPOCH 8 - PROGRESS: at 97.49% examples, 705401 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:41: EPOCH 8: training on 4120761 raw words (2922951 effective words) took 4.1s, 706394 effective words/s
# INFO - 15:39:42: EPOCH 9 - PROGRESS: at 24.33% examples, 684637 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:43: EPOCH 9 - PROGRESS: at 47.89% examples, 680859 words/s, in_qsize 6, out_qsize 0
# INFO - 15:39:44: EPOCH 9 - PROGRESS: at 71.67% examples, 680494 words/s, in_qsize 5, out_qsize 0
# INFO - 15:39:45: EPOCH 9 - PROGRESS: at 95.10% examples, 685459 words/s, in_qsize 6, out_qsize 0
# INFO - 15:39:45: EPOCH 9: training on 4120761 raw words (2922577 effective words) took 4.3s, 687612 effective words/s
# INFO - 15:39:45: Word2Vec lifecycle event {'msg': 'training on 41207610 raw words (29232574 effective words) took 44.0s, 664761 effective words/s', 'datetime': '2023-04-22T15:39:45.438349', 'gensim': '4.3.1', 'python': '3.8.3 (default, Jul  2 2020, 16:21:59) \n[GCC 7.3.0]', 'platform': 'Linux-5.15.0-69-generic-x86_64-with-glibc2.10', 'event': 'train'}
# INFO - 15:39:45: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=7358, vector_size=100, alpha=0.025>', 'datetime': '2023-04-22T15:39:45.439609', 'gensim': '4.3.1', 'python': '3.8.3 (default, Jul  2 2020, 16:21:59) \n[GCC 7.3.0]', 'platform': 'Linux-5.15.0-69-generic-x86_64-with-glibc2.10', 'event': 'created'}
# INFO - 15:39:45: Word2Vec lifecycle event {'fname_or_handle': './data/recipe2vec_b1ab383571494a9d8b9b66212e5b216a.model', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2023-04-22T15:39:45.440238', 'gensim': '4.3.1', 'python': '3.8.3 (default, Jul  2 2020, 16:21:59) \n[GCC 7.3.0]', 'platform': 'Linux-5.15.0-69-generic-x86_64-with-glibc2.10', 'event': 'saving'}
# INFO - 15:39:45: not storing attribute cum_table
# INFO - 15:39:45: saved ./data/recipe2vec_b1ab383571494a9d8b9b66212e5b216a.model
# INFO - 15:40:11: collecting all words and their counts
# INFO - 15:40:11: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 15:40:11: PROGRESS: at sentence #10000, processed 78783 words, keeping 3498 word types
# INFO - 15:40:11: PROGRESS: at sentence #20000, processed 156666 words, keeping 4106 word types
# INFO - 15:40:11: PROGRESS: at sentence #30000, processed 234118 words, keeping 4459 word types
# INFO - 15:40:11: PROGRESS: at sentence #40000, processed 312517 words, keeping 4694 word types
# INFO - 15:40:11: PROGRESS: at sentence #50000, processed 392108 words, keeping 4858 word types
# INFO - 15:40:11: PROGRESS: at sentence #60000, processed 471699 words, keeping 5007 word types
# INFO - 15:40:11: PROGRESS: at sentence #70000, processed 550299 words, keeping 5126 word types
# INFO - 15:40:11: PROGRESS: at sentence #80000, processed 631287 words, keeping 5227 word types
# INFO - 15:40:11: PROGRESS: at sentence #90000, processed 712934 words, keeping 5395 word types
# INFO - 15:40:11: PROGRESS: at sentence #100000, processed 793311 words, keeping 5573 word types
# INFO - 15:40:11: PROGRESS: at sentence #110000, processed 875780 words, keeping 5721 word types
# INFO - 15:40:11: PROGRESS: at sentence #120000, processed 953574 words, keeping 5787 word types
# INFO - 15:40:11: PROGRESS: at sentence #130000, processed 1034017 words, keeping 5842 word types
# INFO - 15:40:11: PROGRESS: at sentence #140000, processed 1115188 words, keeping 5906 word types
# INFO - 15:40:11: PROGRESS: at sentence #150000, processed 1193851 words, keeping 5967 word types
# INFO - 15:40:11: PROGRESS: at sentence #160000, processed 1273109 words, keeping 6032 word types
# INFO - 15:40:11: PROGRESS: at sentence #170000, processed 1351713 words, keeping 6073 word types
# INFO - 15:40:11: PROGRESS: at sentence #180000, processed 1432251 words, keeping 6126 word types
# INFO - 15:40:11: PROGRESS: at sentence #190000, processed 1513299 words, keeping 6169 word types
# INFO - 15:40:12: PROGRESS: at sentence #200000, processed 1594181 words, keeping 6212 word types
# INFO - 15:40:12: PROGRESS: at sentence #210000, processed 1673262 words, keeping 6262 word types
# INFO - 15:40:12: PROGRESS: at sentence #220000, processed 1753135 words, keeping 6310 word types
# INFO - 15:40:12: PROGRESS: at sentence #230000, processed 1831365 words, keeping 6358 word types
# INFO - 15:40:12: PROGRESS: at sentence #240000, processed 1909358 words, keeping 6390 word types
# INFO - 15:40:12: PROGRESS: at sentence #250000, processed 1988304 words, keeping 6433 word types
# INFO - 15:40:12: PROGRESS: at sentence #260000, processed 2066882 words, keeping 6464 word types
# INFO - 15:40:12: PROGRESS: at sentence #270000, processed 2146775 words, keeping 6495 word types
# INFO - 15:40:12: PROGRESS: at sentence #280000, processed 2225474 words, keeping 6523 word types
# INFO - 15:40:12: PROGRESS: at sentence #290000, processed 2302840 words, keeping 6554 word types
# INFO - 15:40:12: PROGRESS: at sentence #300000, processed 2381100 words, keeping 6583 word types
# INFO - 15:40:12: PROGRESS: at sentence #310000, processed 2459562 words, keeping 6612 word types
# INFO - 15:40:12: PROGRESS: at sentence #320000, processed 2540749 words, keeping 6646 word types
# INFO - 15:40:12: PROGRESS: at sentence #330000, processed 2620439 words, keeping 6670 word types
# INFO - 15:40:12: PROGRESS: at sentence #340000, processed 2701943 words, keeping 6703 word types
# INFO - 15:40:12: PROGRESS: at sentence #350000, processed 2782900 words, keeping 6733 word types
# INFO - 15:40:12: PROGRESS: at sentence #360000, processed 2863945 words, keeping 6791 word types
# INFO - 15:40:12: PROGRESS: at sentence #370000, processed 2945972 words, keeping 6827 word types
# INFO - 15:40:12: PROGRESS: at sentence #380000, processed 3027762 words, keeping 6857 word types
# INFO - 15:40:12: PROGRESS: at sentence #390000, processed 3110306 words, keeping 6899 word types
# INFO - 15:40:12: PROGRESS: at sentence #400000, processed 3192242 words, keeping 6939 word types
# INFO - 15:40:12: PROGRESS: at sentence #410000, processed 3272235 words, keeping 6977 word types
# INFO - 15:40:12: PROGRESS: at sentence #420000, processed 3356013 words, keeping 7007 word types
# INFO - 15:40:12: PROGRESS: at sentence #430000, processed 3437614 words, keeping 7036 word types
# INFO - 15:40:12: PROGRESS: at sentence #440000, processed 3518441 words, keeping 7071 word types
# INFO - 15:40:12: PROGRESS: at sentence #450000, processed 3602971 words, keeping 7114 word types
# INFO - 15:40:12: PROGRESS: at sentence #460000, processed 3686573 words, keeping 7179 word types
# INFO - 15:40:12: PROGRESS: at sentence #470000, processed 3770651 words, keeping 7216 word types
# INFO - 15:40:12: PROGRESS: at sentence #480000, processed 3855474 words, keeping 7256 word types
# INFO - 15:40:12: PROGRESS: at sentence #490000, processed 3936148 words, keeping 7296 word types
# INFO - 15:40:12: PROGRESS: at sentence #500000, processed 4018371 words, keeping 7305 word types
# INFO - 15:40:12: PROGRESS: at sentence #510000, processed 4106690 words, keeping 7358 word types
# INFO - 15:40:12: collected 7358 word types from a corpus of 4120761 raw words and 511626 sentences
# INFO - 15:40:12: Creating a fresh vocabulary
# INFO - 15:40:12: Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 7358 unique words (100.00% of original 7358, drops 0)', 'datetime': '2023-04-22T15:40:12.518155', 'gensim': '4.3.1', 'python': '3.8.3 (default, Jul  2 2020, 16:21:59) \n[GCC 7.3.0]', 'platform': 'Linux-5.15.0-69-generic-x86_64-with-glibc2.10', 'event': 'prepare_vocab'}
# INFO - 15:40:12: Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 4120761 word corpus (100.00% of original 4120761, drops 0)', 'datetime': '2023-04-22T15:40:12.519289', 'gensim': '4.3.1', 'python': '3.8.3 (default, Jul  2 2020, 16:21:59) \n[GCC 7.3.0]', 'platform': 'Linux-5.15.0-69-generic-x86_64-with-glibc2.10', 'event': 'prepare_vocab'}
# INFO - 15:40:12: deleting the raw counts dictionary of 7358 items
# INFO - 15:40:12: sample=0.001 downsamples 67 most-common words
# INFO - 15:40:12: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 2922964.5935400887 word corpus (70.9%% of prior 4120761)', 'datetime': '2023-04-22T15:40:12.565060', 'gensim': '4.3.1', 'python': '3.8.3 (default, Jul  2 2020, 16:21:59) \n[GCC 7.3.0]', 'platform': 'Linux-5.15.0-69-generic-x86_64-with-glibc2.10', 'event': 'prepare_vocab'}
# INFO - 15:40:12: estimated required memory for 7358 words and 100 dimensions: 9565400 bytes
# INFO - 15:40:12: resetting layer weights
# INFO - 15:40:12: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-04-22T15:40:12.628824', 'gensim': '4.3.1', 'python': '3.8.3 (default, Jul  2 2020, 16:21:59) \n[GCC 7.3.0]', 'platform': 'Linux-5.15.0-69-generic-x86_64-with-glibc2.10', 'event': 'build_vocab'}
# INFO - 15:40:12: Word2Vec lifecycle event {'msg': 'training model with 3 workers on 7358 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2023-04-22T15:40:12.629375', 'gensim': '4.3.1', 'python': '3.8.3 (default, Jul  2 2020, 16:21:59) \n[GCC 7.3.0]', 'platform': 'Linux-5.15.0-69-generic-x86_64-with-glibc2.10', 'event': 'train'}
# INFO - 15:40:13: EPOCH 0 - PROGRESS: at 26.26% examples, 736639 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:14: EPOCH 0 - PROGRESS: at 52.58% examples, 745266 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:15: EPOCH 0 - PROGRESS: at 78.34% examples, 747117 words/s, in_qsize 6, out_qsize 0
# INFO - 15:40:16: EPOCH 0: training on 4120761 raw words (2922282 effective words) took 3.9s, 749845 effective words/s
# INFO - 15:40:17: EPOCH 1 - PROGRESS: at 26.26% examples, 740897 words/s, in_qsize 6, out_qsize 0
# INFO - 15:40:18: EPOCH 1 - PROGRESS: at 52.83% examples, 751746 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:19: EPOCH 1 - PROGRESS: at 79.30% examples, 759000 words/s, in_qsize 6, out_qsize 0
# INFO - 15:40:20: EPOCH 1: training on 4120761 raw words (2922630 effective words) took 3.9s, 744368 effective words/s
# INFO - 15:40:21: EPOCH 2 - PROGRESS: at 25.54% examples, 716838 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:22: EPOCH 2 - PROGRESS: at 50.38% examples, 715280 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:23: EPOCH 2 - PROGRESS: at 75.24% examples, 718308 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:24: EPOCH 2 - PROGRESS: at 98.44% examples, 712961 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:24: EPOCH 2: training on 4120761 raw words (2922667 effective words) took 4.1s, 714733 effective words/s
# INFO - 15:40:25: EPOCH 3 - PROGRESS: at 25.06% examples, 701047 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:26: EPOCH 3 - PROGRESS: at 50.13% examples, 709525 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:27: EPOCH 3 - PROGRESS: at 75.01% examples, 711712 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:28: EPOCH 3 - PROGRESS: at 97.25% examples, 702382 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:28: EPOCH 3: training on 4120761 raw words (2923000 effective words) took 4.2s, 703716 effective words/s
# INFO - 15:40:29: EPOCH 4 - PROGRESS: at 25.30% examples, 714581 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:30: EPOCH 4 - PROGRESS: at 50.63% examples, 720657 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:31: EPOCH 4 - PROGRESS: at 75.24% examples, 717003 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:32: EPOCH 4 - PROGRESS: at 97.96% examples, 710135 words/s, in_qsize 6, out_qsize 0
# INFO - 15:40:32: EPOCH 4: training on 4120761 raw words (2922430 effective words) took 4.1s, 710838 effective words/s
# INFO - 15:40:33: EPOCH 5 - PROGRESS: at 25.78% examples, 723961 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:34: EPOCH 5 - PROGRESS: at 51.13% examples, 723774 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:35: EPOCH 5 - PROGRESS: at 75.95% examples, 722712 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:36: EPOCH 5 - PROGRESS: at 99.50% examples, 721279 words/s, in_qsize 3, out_qsize 0
# INFO - 15:40:36: EPOCH 5: training on 4120761 raw words (2923297 effective words) took 4.1s, 721708 effective words/s
# INFO - 15:40:37: EPOCH 6 - PROGRESS: at 25.54% examples, 716112 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:38: EPOCH 6 - PROGRESS: at 50.87% examples, 721293 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:39: EPOCH 6 - PROGRESS: at 75.48% examples, 719423 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:40: EPOCH 6 - PROGRESS: at 98.44% examples, 714098 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:40: EPOCH 6: training on 4120761 raw words (2923792 effective words) took 4.1s, 715035 effective words/s
# INFO - 15:40:42: EPOCH 7 - PROGRESS: at 25.06% examples, 706706 words/s, in_qsize 6, out_qsize 0
# INFO - 15:40:43: EPOCH 7 - PROGRESS: at 49.63% examples, 707457 words/s, in_qsize 6, out_qsize 0
# INFO - 15:40:44: EPOCH 7 - PROGRESS: at 73.81% examples, 700587 words/s, in_qsize 6, out_qsize 1
# INFO - 15:40:45: EPOCH 7 - PROGRESS: at 97.25% examples, 702045 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:45: EPOCH 7: training on 4120761 raw words (2923196 effective words) took 4.2s, 703405 effective words/s
# INFO - 15:40:46: EPOCH 8 - PROGRESS: at 25.54% examples, 720857 words/s, in_qsize 6, out_qsize 0
# INFO - 15:40:47: EPOCH 8 - PROGRESS: at 49.63% examples, 704502 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:48: EPOCH 8 - PROGRESS: at 74.53% examples, 710428 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:49: EPOCH 8 - PROGRESS: at 97.49% examples, 705099 words/s, in_qsize 6, out_qsize 0
# INFO - 15:40:49: EPOCH 8: training on 4120761 raw words (2923452 effective words) took 4.1s, 707048 effective words/s
# INFO - 15:40:50: EPOCH 9 - PROGRESS: at 25.06% examples, 709288 words/s, in_qsize 6, out_qsize 0
# INFO - 15:40:51: EPOCH 9 - PROGRESS: at 49.38% examples, 704162 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:52: EPOCH 9 - PROGRESS: at 73.81% examples, 706140 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:53: EPOCH 9 - PROGRESS: at 97.01% examples, 705381 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:53: EPOCH 9: training on 4120761 raw words (2923381 effective words) took 4.1s, 706736 effective words/s
# INFO - 15:40:54: EPOCH 10 - PROGRESS: at 23.60% examples, 667114 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:55: EPOCH 10 - PROGRESS: at 46.91% examples, 669507 words/s, in_qsize 6, out_qsize 0
# INFO - 15:40:56: EPOCH 10 - PROGRESS: at 71.67% examples, 685281 words/s, in_qsize 6, out_qsize 0
# INFO - 15:40:57: EPOCH 10 - PROGRESS: at 94.37% examples, 685775 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:57: EPOCH 10: training on 4120761 raw words (2924139 effective words) took 4.3s, 687867 effective words/s
# INFO - 15:40:58: EPOCH 11 - PROGRESS: at 24.58% examples, 688372 words/s, in_qsize 5, out_qsize 0
# INFO - 15:40:59: EPOCH 11 - PROGRESS: at 50.13% examples, 711524 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:00: EPOCH 11 - PROGRESS: at 75.24% examples, 715372 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:01: EPOCH 11 - PROGRESS: at 97.49% examples, 704817 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:01: EPOCH 11: training on 4120761 raw words (2923490 effective words) took 4.1s, 705732 effective words/s
# INFO - 15:41:02: EPOCH 12 - PROGRESS: at 25.54% examples, 720114 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:03: EPOCH 12 - PROGRESS: at 50.63% examples, 719285 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:04: EPOCH 12 - PROGRESS: at 75.24% examples, 715463 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:05: EPOCH 12 - PROGRESS: at 98.64% examples, 712658 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:05: EPOCH 12: training on 4120761 raw words (2923417 effective words) took 4.1s, 712048 effective words/s
# INFO - 15:41:06: EPOCH 13 - PROGRESS: at 25.54% examples, 723453 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:07: EPOCH 13 - PROGRESS: at 50.63% examples, 721890 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:08: EPOCH 13 - PROGRESS: at 75.01% examples, 715026 words/s, in_qsize 6, out_qsize 0
# INFO - 15:41:10: EPOCH 13 - PROGRESS: at 98.44% examples, 711715 words/s, in_qsize 6, out_qsize 0
# INFO - 15:41:10: EPOCH 13: training on 4120761 raw words (2923434 effective words) took 4.1s, 713199 effective words/s
# INFO - 15:41:11: EPOCH 14 - PROGRESS: at 25.06% examples, 702738 words/s, in_qsize 6, out_qsize 0
# INFO - 15:41:12: EPOCH 14 - PROGRESS: at 49.88% examples, 708990 words/s, in_qsize 6, out_qsize 0
# INFO - 15:41:13: EPOCH 14 - PROGRESS: at 73.81% examples, 702252 words/s, in_qsize 6, out_qsize 0
# INFO - 15:41:14: EPOCH 14 - PROGRESS: at 97.25% examples, 701382 words/s, in_qsize 6, out_qsize 0
# INFO - 15:41:14: EPOCH 14: training on 4120761 raw words (2923342 effective words) took 4.2s, 702616 effective words/s
# INFO - 15:41:15: EPOCH 15 - PROGRESS: at 25.54% examples, 712250 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:16: EPOCH 15 - PROGRESS: at 50.87% examples, 719814 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:17: EPOCH 15 - PROGRESS: at 75.95% examples, 720771 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:18: EPOCH 15 - PROGRESS: at 99.29% examples, 717768 words/s, in_qsize 4, out_qsize 0
# INFO - 15:41:18: EPOCH 15: training on 4120761 raw words (2922594 effective words) took 4.1s, 718530 effective words/s
# INFO - 15:41:19: EPOCH 16 - PROGRESS: at 25.54% examples, 723928 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:20: EPOCH 16 - PROGRESS: at 50.38% examples, 718801 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:21: EPOCH 16 - PROGRESS: at 75.01% examples, 718855 words/s, in_qsize 6, out_qsize 0
# INFO - 15:41:22: EPOCH 16 - PROGRESS: at 98.21% examples, 714224 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:22: EPOCH 16: training on 4120761 raw words (2923387 effective words) took 4.1s, 714076 effective words/s
# INFO - 15:41:23: EPOCH 17 - PROGRESS: at 25.30% examples, 711052 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:24: EPOCH 17 - PROGRESS: at 50.38% examples, 713194 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:25: EPOCH 17 - PROGRESS: at 75.24% examples, 716520 words/s, in_qsize 6, out_qsize 0
# INFO - 15:41:26: EPOCH 17 - PROGRESS: at 98.64% examples, 714883 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:26: EPOCH 17: training on 4120761 raw words (2923028 effective words) took 4.1s, 715218 effective words/s
# INFO - 15:41:27: EPOCH 18 - PROGRESS: at 25.54% examples, 710164 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:28: EPOCH 18 - PROGRESS: at 51.13% examples, 722491 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:29: EPOCH 18 - PROGRESS: at 75.71% examples, 721056 words/s, in_qsize 6, out_qsize 0
# INFO - 15:41:30: EPOCH 18 - PROGRESS: at 98.21% examples, 709747 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:30: EPOCH 18: training on 4120761 raw words (2922718 effective words) took 4.1s, 710845 effective words/s
# INFO - 15:41:31: EPOCH 19 - PROGRESS: at 24.82% examples, 699088 words/s, in_qsize 6, out_qsize 0
# INFO - 15:41:32: EPOCH 19 - PROGRESS: at 50.13% examples, 713754 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:33: EPOCH 19 - PROGRESS: at 74.77% examples, 715146 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:34: EPOCH 19 - PROGRESS: at 97.96% examples, 712272 words/s, in_qsize 6, out_qsize 0
# INFO - 15:41:34: EPOCH 19: training on 4120761 raw words (2923278 effective words) took 4.1s, 713349 effective words/s
# INFO - 15:41:35: EPOCH 20 - PROGRESS: at 25.78% examples, 729014 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:36: EPOCH 20 - PROGRESS: at 51.13% examples, 726476 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:37: EPOCH 20 - PROGRESS: at 75.95% examples, 722884 words/s, in_qsize 6, out_qsize 0
# INFO - 15:41:38: EPOCH 20 - PROGRESS: at 99.29% examples, 719285 words/s, in_qsize 4, out_qsize 0
# INFO - 15:41:38: EPOCH 20: training on 4120761 raw words (2922794 effective words) took 4.1s, 720006 effective words/s
# INFO - 15:41:39: EPOCH 21 - PROGRESS: at 25.54% examples, 720497 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:40: EPOCH 21 - PROGRESS: at 50.87% examples, 721186 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:41: EPOCH 21 - PROGRESS: at 75.24% examples, 718143 words/s, in_qsize 6, out_qsize 0
# INFO - 15:41:42: EPOCH 21 - PROGRESS: at 97.72% examples, 705273 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:42: EPOCH 21: training on 4120761 raw words (2924036 effective words) took 4.1s, 706128 effective words/s
# INFO - 15:41:43: EPOCH 22 - PROGRESS: at 25.30% examples, 714450 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:44: EPOCH 22 - PROGRESS: at 50.87% examples, 725177 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:45: EPOCH 22 - PROGRESS: at 75.48% examples, 723137 words/s, in_qsize 6, out_qsize 0
# INFO - 15:41:46: EPOCH 22 - PROGRESS: at 99.08% examples, 721404 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:46: EPOCH 22: training on 4120761 raw words (2923843 effective words) took 4.0s, 723114 effective words/s
# INFO - 15:41:48: EPOCH 23 - PROGRESS: at 25.78% examples, 719643 words/s, in_qsize 6, out_qsize 0
# INFO - 15:41:49: EPOCH 23 - PROGRESS: at 51.13% examples, 719292 words/s, in_qsize 6, out_qsize 0
# INFO - 15:41:50: EPOCH 23 - PROGRESS: at 75.95% examples, 718944 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:51: EPOCH 23 - PROGRESS: at 99.08% examples, 715254 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:51: EPOCH 23: training on 4120761 raw words (2923392 effective words) took 4.1s, 716585 effective words/s
# INFO - 15:41:52: EPOCH 24 - PROGRESS: at 25.54% examples, 722808 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:53: EPOCH 24 - PROGRESS: at 50.38% examples, 717554 words/s, in_qsize 6, out_qsize 0
# INFO - 15:41:54: EPOCH 24 - PROGRESS: at 75.24% examples, 718069 words/s, in_qsize 6, out_qsize 0
# INFO - 15:41:55: EPOCH 24 - PROGRESS: at 98.64% examples, 715455 words/s, in_qsize 6, out_qsize 0
# INFO - 15:41:55: EPOCH 24: training on 4120761 raw words (2923616 effective words) took 4.1s, 716073 effective words/s
# INFO - 15:41:56: EPOCH 25 - PROGRESS: at 25.06% examples, 705960 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:57: EPOCH 25 - PROGRESS: at 50.38% examples, 715558 words/s, in_qsize 6, out_qsize 0
# INFO - 15:41:58: EPOCH 25 - PROGRESS: at 75.01% examples, 713440 words/s, in_qsize 6, out_qsize 0
# INFO - 15:41:59: EPOCH 25 - PROGRESS: at 97.01% examples, 699425 words/s, in_qsize 5, out_qsize 0
# INFO - 15:41:59: EPOCH 25: training on 4120761 raw words (2922628 effective words) took 4.2s, 701482 effective words/s
# INFO - 15:42:00: EPOCH 26 - PROGRESS: at 25.54% examples, 715568 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:01: EPOCH 26 - PROGRESS: at 45.91% examples, 648429 words/s, in_qsize 6, out_qsize 0
# INFO - 15:42:02: EPOCH 26 - PROGRESS: at 70.96% examples, 669329 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:03: EPOCH 26 - PROGRESS: at 94.83% examples, 682253 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:03: EPOCH 26: training on 4120761 raw words (2922561 effective words) took 4.3s, 683057 effective words/s
# INFO - 15:42:04: EPOCH 27 - PROGRESS: at 25.06% examples, 701897 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:05: EPOCH 27 - PROGRESS: at 50.13% examples, 709031 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:06: EPOCH 27 - PROGRESS: at 75.01% examples, 712773 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:07: EPOCH 27 - PROGRESS: at 98.40% examples, 712094 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:07: EPOCH 27: training on 4120761 raw words (2923974 effective words) took 4.1s, 712905 effective words/s
# INFO - 15:42:08: EPOCH 28 - PROGRESS: at 25.30% examples, 707429 words/s, in_qsize 6, out_qsize 0
# INFO - 15:42:09: EPOCH 28 - PROGRESS: at 49.13% examples, 696683 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:10: EPOCH 28 - PROGRESS: at 72.85% examples, 693633 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:11: EPOCH 28 - PROGRESS: at 96.53% examples, 699306 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:11: EPOCH 28: training on 4120761 raw words (2922197 effective words) took 4.2s, 700696 effective words/s
# INFO - 15:42:12: EPOCH 29 - PROGRESS: at 24.09% examples, 679259 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:13: EPOCH 29 - PROGRESS: at 49.13% examples, 696778 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:14: EPOCH 29 - PROGRESS: at 74.05% examples, 701566 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:15: EPOCH 29 - PROGRESS: at 97.72% examples, 703738 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:16: EPOCH 29: training on 4120761 raw words (2924381 effective words) took 4.1s, 704997 effective words/s
# INFO - 15:42:17: EPOCH 30 - PROGRESS: at 25.06% examples, 705935 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:18: EPOCH 30 - PROGRESS: at 50.63% examples, 717905 words/s, in_qsize 6, out_qsize 0
# INFO - 15:42:19: EPOCH 30 - PROGRESS: at 75.48% examples, 718206 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:20: EPOCH 30 - PROGRESS: at 99.08% examples, 716770 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:20: EPOCH 30: training on 4120761 raw words (2922986 effective words) took 4.1s, 718715 effective words/s
# INFO - 15:42:21: EPOCH 31 - PROGRESS: at 25.54% examples, 721695 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:22: EPOCH 31 - PROGRESS: at 50.87% examples, 721637 words/s, in_qsize 6, out_qsize 0
# INFO - 15:42:23: EPOCH 31 - PROGRESS: at 75.71% examples, 721247 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:24: EPOCH 31 - PROGRESS: at 99.08% examples, 716901 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:24: EPOCH 31: training on 4120761 raw words (2923020 effective words) took 4.1s, 718573 effective words/s
# INFO - 15:42:25: EPOCH 32 - PROGRESS: at 25.06% examples, 707676 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:26: EPOCH 32 - PROGRESS: at 50.38% examples, 716195 words/s, in_qsize 6, out_qsize 0
# INFO - 15:42:27: EPOCH 32 - PROGRESS: at 75.01% examples, 716284 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:28: EPOCH 32 - PROGRESS: at 98.21% examples, 712293 words/s, in_qsize 6, out_qsize 0
# INFO - 15:42:28: EPOCH 32: training on 4120761 raw words (2922358 effective words) took 4.1s, 708052 effective words/s
# INFO - 15:42:29: EPOCH 33 - PROGRESS: at 25.06% examples, 699929 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:30: EPOCH 33 - PROGRESS: at 50.13% examples, 709740 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:31: EPOCH 33 - PROGRESS: at 74.53% examples, 707790 words/s, in_qsize 6, out_qsize 0
# INFO - 15:42:32: EPOCH 33 - PROGRESS: at 97.96% examples, 707506 words/s, in_qsize 6, out_qsize 0
# INFO - 15:42:32: EPOCH 33: training on 4120761 raw words (2922741 effective words) took 4.1s, 707424 effective words/s
# INFO - 15:42:33: EPOCH 34 - PROGRESS: at 25.30% examples, 716656 words/s, in_qsize 6, out_qsize 0
# INFO - 15:42:34: EPOCH 34 - PROGRESS: at 50.13% examples, 714672 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:35: EPOCH 34 - PROGRESS: at 75.01% examples, 716824 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:36: EPOCH 34 - PROGRESS: at 98.44% examples, 714458 words/s, in_qsize 6, out_qsize 0
# INFO - 15:42:36: EPOCH 34: training on 4120761 raw words (2923011 effective words) took 4.1s, 715139 effective words/s
# INFO - 15:42:37: EPOCH 35 - PROGRESS: at 25.06% examples, 706113 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:38: EPOCH 35 - PROGRESS: at 50.13% examples, 714239 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:39: EPOCH 35 - PROGRESS: at 75.01% examples, 716890 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:40: EPOCH 35 - PROGRESS: at 98.44% examples, 713006 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:40: EPOCH 35: training on 4120761 raw words (2922180 effective words) took 4.1s, 714489 effective words/s
# INFO - 15:42:41: EPOCH 36 - PROGRESS: at 25.30% examples, 715962 words/s, in_qsize 6, out_qsize 0
# INFO - 15:42:42: EPOCH 36 - PROGRESS: at 48.88% examples, 696876 words/s, in_qsize 6, out_qsize 0
# INFO - 15:42:43: EPOCH 36 - PROGRESS: at 73.57% examples, 702870 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:44: EPOCH 36 - PROGRESS: at 97.01% examples, 704792 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:44: EPOCH 36: training on 4120761 raw words (2923198 effective words) took 4.1s, 706642 effective words/s
# INFO - 15:42:45: EPOCH 37 - PROGRESS: at 25.06% examples, 707648 words/s, in_qsize 6, out_qsize 0
# INFO - 15:42:46: EPOCH 37 - PROGRESS: at 50.63% examples, 721798 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:47: EPOCH 37 - PROGRESS: at 75.24% examples, 720569 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:48: EPOCH 37 - PROGRESS: at 99.08% examples, 719766 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:48: EPOCH 37: training on 4120761 raw words (2922822 effective words) took 4.1s, 720962 effective words/s
# INFO - 15:42:49: EPOCH 38 - PROGRESS: at 25.78% examples, 716462 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:50: EPOCH 38 - PROGRESS: at 51.37% examples, 725254 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:51: EPOCH 38 - PROGRESS: at 76.19% examples, 724852 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:52: EPOCH 38 - PROGRESS: at 99.55% examples, 721074 words/s, in_qsize 2, out_qsize 1
# INFO - 15:42:52: EPOCH 38: training on 4120761 raw words (2923118 effective words) took 4.1s, 721321 effective words/s
# INFO - 15:42:53: EPOCH 39 - PROGRESS: at 25.54% examples, 716603 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:54: EPOCH 39 - PROGRESS: at 50.87% examples, 722082 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:55: EPOCH 39 - PROGRESS: at 75.71% examples, 721367 words/s, in_qsize 5, out_qsize 0
# INFO - 15:42:56: EPOCH 39 - PROGRESS: at 97.96% examples, 710133 words/s, in_qsize 6, out_qsize 0
# INFO - 15:42:57: EPOCH 39: training on 4120761 raw words (2922149 effective words) took 4.1s, 710409 effective words/s
# INFO - 15:42:58: EPOCH 40 - PROGRESS: at 25.06% examples, 707213 words/s, in_qsize 6, out_qsize 0
# INFO - 15:42:59: EPOCH 40 - PROGRESS: at 50.38% examples, 717534 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:00: EPOCH 40 - PROGRESS: at 75.24% examples, 718853 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:01: EPOCH 40 - PROGRESS: at 98.40% examples, 713214 words/s, in_qsize 6, out_qsize 0
# INFO - 15:43:01: EPOCH 40: training on 4120761 raw words (2922883 effective words) took 4.1s, 714588 effective words/s
# INFO - 15:43:02: EPOCH 41 - PROGRESS: at 25.54% examples, 719593 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:03: EPOCH 41 - PROGRESS: at 50.63% examples, 720539 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:04: EPOCH 41 - PROGRESS: at 75.48% examples, 722722 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:05: EPOCH 41 - PROGRESS: at 98.86% examples, 719999 words/s, in_qsize 6, out_qsize 0
# INFO - 15:43:05: EPOCH 41: training on 4120761 raw words (2924073 effective words) took 4.1s, 721711 effective words/s
# INFO - 15:43:06: EPOCH 42 - PROGRESS: at 25.78% examples, 721021 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:07: EPOCH 42 - PROGRESS: at 50.87% examples, 721695 words/s, in_qsize 6, out_qsize 0
# INFO - 15:43:08: EPOCH 42 - PROGRESS: at 75.48% examples, 719150 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:09: EPOCH 42 - PROGRESS: at 99.08% examples, 716746 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:09: EPOCH 42: training on 4120761 raw words (2923416 effective words) took 4.1s, 718599 effective words/s
# INFO - 15:43:10: EPOCH 43 - PROGRESS: at 25.30% examples, 713199 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:11: EPOCH 43 - PROGRESS: at 50.87% examples, 724615 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:12: EPOCH 43 - PROGRESS: at 75.71% examples, 715031 words/s, in_qsize 4, out_qsize 1
# INFO - 15:43:13: EPOCH 43 - PROGRESS: at 98.64% examples, 710981 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:13: EPOCH 43: training on 4120761 raw words (2923787 effective words) took 4.1s, 711742 effective words/s
# INFO - 15:43:14: EPOCH 44 - PROGRESS: at 25.30% examples, 716022 words/s, in_qsize 6, out_qsize 0
# INFO - 15:43:15: EPOCH 44 - PROGRESS: at 50.38% examples, 716392 words/s, in_qsize 6, out_qsize 0
# INFO - 15:43:16: EPOCH 44 - PROGRESS: at 75.48% examples, 720409 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:17: EPOCH 44 - PROGRESS: at 98.44% examples, 713068 words/s, in_qsize 6, out_qsize 0
# INFO - 15:43:17: EPOCH 44: training on 4120761 raw words (2923248 effective words) took 4.1s, 713358 effective words/s
# INFO - 15:43:18: EPOCH 45 - PROGRESS: at 25.06% examples, 704329 words/s, in_qsize 6, out_qsize 0
# INFO - 15:43:19: EPOCH 45 - PROGRESS: at 50.13% examples, 712273 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:20: EPOCH 45 - PROGRESS: at 75.24% examples, 719103 words/s, in_qsize 6, out_qsize 0
# INFO - 15:43:21: EPOCH 45 - PROGRESS: at 98.40% examples, 715601 words/s, in_qsize 6, out_qsize 0
# INFO - 15:43:21: EPOCH 45: training on 4120761 raw words (2923248 effective words) took 4.1s, 717228 effective words/s
# INFO - 15:43:22: EPOCH 46 - PROGRESS: at 25.54% examples, 722705 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:23: EPOCH 46 - PROGRESS: at 50.38% examples, 716974 words/s, in_qsize 6, out_qsize 0
# INFO - 15:43:24: EPOCH 46 - PROGRESS: at 75.24% examples, 718880 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:25: EPOCH 46 - PROGRESS: at 98.40% examples, 715145 words/s, in_qsize 6, out_qsize 0
# INFO - 15:43:25: EPOCH 46: training on 4120761 raw words (2922405 effective words) took 4.1s, 716732 effective words/s
# INFO - 15:43:26: EPOCH 47 - PROGRESS: at 25.06% examples, 708380 words/s, in_qsize 6, out_qsize 0
# INFO - 15:43:27: EPOCH 47 - PROGRESS: at 50.38% examples, 718246 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:28: EPOCH 47 - PROGRESS: at 73.81% examples, 706527 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:29: EPOCH 47 - PROGRESS: at 97.25% examples, 706230 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:29: EPOCH 47: training on 4120761 raw words (2923481 effective words) took 4.1s, 707059 effective words/s
# INFO - 15:43:30: EPOCH 48 - PROGRESS: at 25.54% examples, 718442 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:31: EPOCH 48 - PROGRESS: at 50.38% examples, 713960 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:32: EPOCH 48 - PROGRESS: at 75.24% examples, 717709 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:33: EPOCH 48 - PROGRESS: at 98.44% examples, 713761 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:33: EPOCH 48: training on 4120761 raw words (2922847 effective words) took 4.1s, 715505 effective words/s
# INFO - 15:43:34: EPOCH 49 - PROGRESS: at 25.54% examples, 719073 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:35: EPOCH 49 - PROGRESS: at 50.87% examples, 722079 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:36: EPOCH 49 - PROGRESS: at 75.71% examples, 720203 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:37: EPOCH 49 - PROGRESS: at 99.08% examples, 715513 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:37: EPOCH 49: training on 4120761 raw words (2924288 effective words) took 4.1s, 717169 effective words/s
# INFO - 15:43:39: EPOCH 50 - PROGRESS: at 24.09% examples, 679272 words/s, in_qsize 6, out_qsize 0
# INFO - 15:43:40: EPOCH 50 - PROGRESS: at 48.88% examples, 694870 words/s, in_qsize 6, out_qsize 0
# INFO - 15:43:41: EPOCH 50 - PROGRESS: at 73.81% examples, 704328 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:42: EPOCH 50 - PROGRESS: at 97.25% examples, 705101 words/s, in_qsize 6, out_qsize 0
# INFO - 15:43:42: EPOCH 50: training on 4120761 raw words (2922349 effective words) took 4.1s, 705942 effective words/s
# INFO - 15:43:43: EPOCH 51 - PROGRESS: at 25.30% examples, 714970 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:44: EPOCH 51 - PROGRESS: at 50.38% examples, 717789 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:45: EPOCH 51 - PROGRESS: at 75.24% examples, 719590 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:46: EPOCH 51 - PROGRESS: at 98.86% examples, 717817 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:46: EPOCH 51: training on 4120761 raw words (2923144 effective words) took 4.1s, 718778 effective words/s
# INFO - 15:43:47: EPOCH 52 - PROGRESS: at 25.54% examples, 716684 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:48: EPOCH 52 - PROGRESS: at 50.87% examples, 722757 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:49: EPOCH 52 - PROGRESS: at 75.48% examples, 720194 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:50: EPOCH 52 - PROGRESS: at 98.86% examples, 717478 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:50: EPOCH 52: training on 4120761 raw words (2923274 effective words) took 4.1s, 718441 effective words/s
# INFO - 15:43:51: EPOCH 53 - PROGRESS: at 25.06% examples, 706865 words/s, in_qsize 6, out_qsize 0
# INFO - 15:43:52: EPOCH 53 - PROGRESS: at 48.88% examples, 689910 words/s, in_qsize 5, out_qsize 0
# INFO - 15:43:53: EPOCH 53 - PROGRESS: at 73.33% examples, 696071 words/s, in_qsize 6, out_qsize 0
# INFO - 15:43:54: EPOCH 53 - PROGRESS: at 96.53% examples, 697261 words/s, in_qsize 5, out_qsize 0
# ...
# INFO - 16:55:36: PROGRESS: at sentence #470000, processed 3770651 words, keeping 7216 word types
# INFO - 16:55:36: PROGRESS: at sentence #480000, processed 3855474 words, keeping 7256 word types
# INFO - 16:55:36: PROGRESS: at sentence #490000, processed 3936148 words, keeping 7296 word types
# INFO - 16:55:36: PROGRESS: at sentence #500000, processed 4018371 words, keeping 7305 word types
# INFO - 16:55:36: PROGRESS: at sentence #510000, processed 4106690 words, keeping 7358 word types
# INFO - 16:55:36: collected 7358 word types from a corpus of 4120761 raw words and 511626 sentences
# INFO - 16:55:36: Creating a fresh vocabulary
# INFO - 16:55:36: Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 7358 unique words (100.00% of original 7358, drops 0)', 'datetime': '2023-04-22T16:55:36.662801', 'gensim': '4.3.1', 'python': '3.8.3 (default, Jul  2 2020, 16:21:59) \n[GCC 7.3.0]', 'platform': 'Linux-5.15.0-69-generic-x86_64-with-glibc2.10', 'event': 'prepare_vocab'}
# INFO - 16:55:36: Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 4120761 word corpus (100.00% of original 4120761, drops 0)', 'datetime': '2023-04-22T16:55:36.664926', 'gensim': '4.3.1', 'python': '3.8.3 (default, Jul  2 2020, 16:21:59) \n[GCC 7.3.0]', 'platform': 'Linux-5.15.0-69-generic-x86_64-with-glibc2.10', 'event': 'prepare_vocab'}
# INFO - 16:55:36: deleting the raw counts dictionary of 7358 items
# INFO - 16:55:36: sample=0.001 downsamples 67 most-common words
# INFO - 16:55:36: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 2922964.5935400887 word corpus (70.9%% of prior 4120761)', 'datetime': '2023-04-22T16:55:36.769167', 'gensim': '4.3.1', 'python': '3.8.3 (default, Jul  2 2020, 16:21:59) \n[GCC 7.3.0]', 'platform': 'Linux-5.15.0-69-generic-x86_64-with-glibc2.10', 'event': 'prepare_vocab'}
# INFO - 16:55:36: estimated required memory for 7358 words and 100 dimensions: 9565400 bytes
# INFO - 16:55:36: resetting layer weights
# INFO - 16:55:36: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-04-22T16:55:36.907599', 'gensim': '4.3.1', 'python': '3.8.3 (default, Jul  2 2020, 16:21:59) \n[GCC 7.3.0]', 'platform': 'Linux-5.15.0-69-generic-x86_64-with-glibc2.10', 'event': 'build_vocab'}
# INFO - 16:55:36: Word2Vec lifecycle event {'msg': 'training model with 3 workers on 7358 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2023-04-22T16:55:36.910933', 'gensim': '4.3.1', 'python': '3.8.3 (default, Jul  2 2020, 16:21:59) \n[GCC 7.3.0]', 'platform': 'Linux-5.15.0-69-generic-x86_64-with-glibc2.10', 'event': 'train'}
# INFO - 16:55:37: EPOCH 0 - PROGRESS: at 10.95% examples, 297516 words/s, in_qsize 5, out_qsize 0
# INFO - 16:55:38: EPOCH 0 - PROGRESS: at 22.61% examples, 312557 words/s, in_qsize 6, out_qsize 0
# INFO - 16:55:40: EPOCH 0 - PROGRESS: at 34.16% examples, 318301 words/s, in_qsize 5, out_qsize 0
# INFO - 16:55:41: EPOCH 0 - PROGRESS: at 46.16% examples, 324370 words/s, in_qsize 5, out_qsize 0
# INFO - 16:55:42: EPOCH 0 - PROGRESS: at 58.58% examples, 329544 words/s, in_qsize 5, out_qsize 0
# INFO - 16:55:43: EPOCH 0 - PROGRESS: at 70.48% examples, 332478 words/s, in_qsize 6, out_qsize 0
# INFO - 16:55:44: EPOCH 0 - PROGRESS: at 85.53% examples, 348347 words/s, in_qsize 5, out_qsize 0
# INFO - 16:55:45: EPOCH 0: training on 4120761 raw words (2922247 effective words) took 8.1s, 362446 effective words/s
# INFO - 16:55:46: EPOCH 1 - PROGRESS: at 13.43% examples, 371998 words/s, in_qsize 5, out_qsize 0
# INFO - 16:55:47: EPOCH 1 - PROGRESS: at 28.96% examples, 406861 words/s, in_qsize 5, out_qsize 0
# INFO - 16:55:48: EPOCH 1 - PROGRESS: at 49.63% examples, 468947 words/s, in_qsize 5, out_qsize 0
# INFO - 16:55:49: EPOCH 1 - PROGRESS: at 72.85% examples, 519593 words/s, in_qsize 5, out_qsize 0
# INFO - 16:55:50: EPOCH 1 - PROGRESS: at 94.60% examples, 547073 words/s, in_qsize 5, out_qsize 0
# INFO - 16:55:50: EPOCH 1: training on 4120761 raw words (2923168 effective words) took 5.5s, 534687 effective words/s
# INFO - 16:55:51: EPOCH 2 - PROGRESS: at 22.35% examples, 618350 words/s, in_qsize 5, out_qsize 1
# INFO - 16:55:52: EPOCH 2 - PROGRESS: at 40.94% examples, 572678 words/s, in_qsize 5, out_qsize 0
# INFO - 16:55:53: EPOCH 2 - PROGRESS: at 56.33% examples, 528873 words/s, in_qsize 5, out_qsize 0
# INFO - 16:55:54: EPOCH 2 - PROGRESS: at 70.48% examples, 497736 words/s, in_qsize 5, out_qsize 0
# INFO - 16:55:55: EPOCH 2 - PROGRESS: at 88.80% examples, 507297 words/s, in_qsize 5, out_qsize 0
# INFO - 16:55:56: EPOCH 2: training on 4120761 raw words (2923439 effective words) took 5.7s, 511967 effective words/s
# INFO - 16:55:57: EPOCH 3 - PROGRESS: at 19.70% examples, 555107 words/s, in_qsize 6, out_qsize 1
# INFO - 16:55:58: EPOCH 3 - PROGRESS: at 32.18% examples, 453766 words/s, in_qsize 5, out_qsize 0
# INFO - 16:55:59: EPOCH 3 - PROGRESS: at 43.90% examples, 415072 words/s, in_qsize 5, out_qsize 0
# INFO - 16:56:00: EPOCH 3 - PROGRESS: at 58.33% examples, 411045 words/s, in_qsize 5, out_qsize 0
# INFO - 16:56:01: EPOCH 3 - PROGRESS: at 71.67% examples, 405042 words/s, in_qsize 5, out_qsize 1
# INFO - 16:56:02: EPOCH 3 - PROGRESS: at 81.91% examples, 388155 words/s, in_qsize 5, out_qsize 0
# INFO - 16:56:03: EPOCH 3 - PROGRESS: at 90.17% examples, 368560 words/s, in_qsize 3, out_qsize 2
# INFO - 16:56:04: EPOCH 3 - PROGRESS: at 97.01% examples, 348353 words/s, in_qsize 5, out_qsize 0
# INFO - 16:56:04: EPOCH 3: training on 4120761 raw words (2924479 effective words) took 8.4s, 347817 effective words/s
# INFO - 16:56:06: EPOCH 4 - PROGRESS: at 10.20% examples, 236281 words/s, in_qsize 5, out_qsize 2
# INFO - 16:56:07: EPOCH 4 - PROGRESS: at 20.66% examples, 258265 words/s, in_qsize 6, out_qsize 0
# INFO - 16:56:08: EPOCH 4 - PROGRESS: at 32.93% examples, 285416 words/s, in_qsize 5, out_qsize 0
# INFO - 16:56:09: EPOCH 4 - PROGRESS: at 45.66% examples, 300061 words/s, in_qsize 5, out_qsize 0
# INFO - 16:56:10: EPOCH 4 - PROGRESS: at 57.84% examples, 308640 words/s, in_qsize 5, out_qsize 0
# INFO - 16:56:11: EPOCH 4 - PROGRESS: at 71.20% examples, 320623 words/s, in_qsize 5, out_qsize 0
# INFO - 16:56:12: EPOCH 4 - PROGRESS: at 83.11% examples, 324371 words/s, in_qsize 6, out_qsize 0
# INFO - 16:56:13: EPOCH 4 - PROGRESS: at 94.87% examples, 328708 words/s, in_qsize 5, out_qsize 0
# INFO - 16:56:13: EPOCH 4: training on 4120761 raw words (2922482 effective words) took 8.9s, 327270 effective words/s
# INFO - 16:56:14: EPOCH 5 - PROGRESS: at 10.70% examples, 297027 words/s, in_qsize 6, out_qsize 0
# INFO - 16:56:15: EPOCH 5 - PROGRESS: at 24.33% examples, 343087 words/s, in_qsize 5, out_qsize 0
# INFO - 16:56:16: EPOCH 5 - PROGRESS: at 38.24% examples, 360658 words/s, in_qsize 5, out_qsize 0
# INFO - 16:56:17: EPOCH 5 - PROGRESS: at 51.62% examples, 361039 words/s, in_qsize 5, out_qsize 0
# INFO - 16:56:18: EPOCH 5 - PROGRESS: at 62.49% examples, 348272 words/s, in_qsize 5, out_qsize 0
# INFO - 16:56:19: EPOCH 5 - PROGRESS: at 73.57% examples, 344627 words/s, in_qsize 5, out_qsize 0
# INFO - 16:56:20: EPOCH 5 - PROGRESS: at 82.86% examples, 335077 words/s, in_qsize 5, out_qsize 0
# INFO - 16:56:22: EPOCH 5 - PROGRESS: at 92.97% examples, 331098 words/s, in_qsize 5, out_qsize 0
# INFO - 16:56:22: EPOCH 5: training on 4120761 raw words (2922223 effective words) took 8.8s, 332269 effective words/s
# INFO - 16:56:23: EPOCH 6 - PROGRESS: at 11.20% examples, 311554 words/s, in_qsize 6, out_qsize 0
# INFO - 16:56:24: EPOCH 6 - PROGRESS: at 24.09% examples, 339821 words/s, in_qsize 5, out_qsize 0
# INFO - 16:56:25: EPOCH 6 - PROGRESS: at 36.55% examples, 344767 words/s, in_qsize 6, out_qsize 0
# INFO - 16:56:26: EPOCH 6 - PROGRESS: at 49.88% examples, 353882 words/s, in_qsize 5, out_qsize 0
# INFO - 16:56:27: EPOCH 6 - PROGRESS: at 61.52% examples, 350139 words/s, in_qsize 6, out_qsize 0
# INFO - 16:56:28: EPOCH 6 - PROGRESS: at 72.62% examples, 344720 words/s, in_qsize 5, out_qsize 0
# INFO - 16:56:29: EPOCH 6 - PROGRESS: at 84.07% examples, 344036 words/s, in_qsize 5, out_qsize 0
# INFO - 16:56:30: EPOCH 6 - PROGRESS: at 93.65% examples, 337331 words/s, in_qsize 5, out_qsize 0
# INFO - 16:56:31: EPOCH 6: training on 4120761 raw words (2923869 effective words) took 8.6s, 338021 effective words/s
# INFO - 16:56:32: EPOCH 7 - PROGRESS: at 11.20% examples, 302481 words/s, in_qsize 5, out_qsize 1
# INFO - 16:56:33: EPOCH 7 - PROGRESS: at 25.06% examples, 347910 words/s, in_qsize 6, out_qsize 0
# INFO - 16:56:34: EPOCH 7 - PROGRESS: at 38.49% examples, 360838 words/s, in_qsize 5, out_qsize 0
# INFO - 16:56:35: EPOCH 7 - PROGRESS: at 51.13% examples, 358259 words/s, in_qsize 5, out_qsize 0
# INFO - 16:56:36: EPOCH 7 - PROGRESS: at 62.99% examples, 355057 words/s, in_qsize 4, out_qsize 1
# INFO - 16:56:37: EPOCH 7 - PROGRESS: at 72.85% examples, 344682 words/s, in_qsize 5, out_qsize 0
# INFO - 16:56:38: EPOCH 7 - PROGRESS: at 82.16% examples, 333098 words/s, in_qsize 5, out_qsize 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/jake/diss/recipe2vec_investigation.ipynb Cell 3 in 9
#       <a href='vscode-notebook-cell:/home/jake/diss/recipe2vec_investigation.ipynb#X45sZmlsZQ%3D%3D?line=5'>6</a> losses = {}
#       <a href='vscode-notebook-cell:/home/jake/diss/recipe2vec_investigation.ipynb#X45sZmlsZQ%3D%3D?line=7'>8</a> for alpha, num_epochs in list(itertools.product(alphas, epochs)):
# ----> <a href='vscode-notebook-cell:/home/jake/diss/recipe2vec_investigation.ipynb#X45sZmlsZQ%3D%3D?line=8'>9</a>     systems["recipe2vec"] = Recipe2Vec(
#      <a href='vscode-notebook-cell:/home/jake/diss/recipe2vec_investigation.ipynb#X45sZmlsZQ%3D%3D?line=9'>10</a>         # model_path="./recipe_rec/data/recipe2vec_42d574c155524a28a8ae6ee691d96e85.model",
#      <a href='vscode-notebook-cell:/home/jake/diss/recipe2vec_investigation.ipynb#X45sZmlsZQ%3D%3D?line=10'>11</a>         alpha=alpha,
#      <a href='vscode-notebook-cell:/home/jake/diss/recipe2vec_investigation.ipynb#X45sZmlsZQ%3D%3D?line=11'>12</a>         num_epochs=num_epochs,
#      <a href='vscode-notebook-cell:/home/jake/diss/recipe2vec_investigation.ipynb#X45sZmlsZQ%3D%3D?line=12'>13</a>         # index_path="./recipe_rec/data/recipe2vec_7153b2f49949474495fd9ffe8b340baf.ann",
#      <a href='vscode-notebook-cell:/home/jake/diss/recipe2vec_investigation.ipynb#X45sZmlsZQ%3D%3D?line=13'>14</a>         verbose=False,
#      <a href='vscode-notebook-cell:/home/jake/diss/recipe2vec_investigation.ipynb#X45sZmlsZQ%3D%3D?line=14'>15</a>     )
#      <a href='vscode-notebook-cell:/home/jake/diss/recipe2vec_investigation.ipynb#X45sZmlsZQ%3D%3D?line=16'>17</a>     training_losses = systems["recipe2vec"].training_losses
#      <a href='vscode-notebook-cell:/home/jake/diss/recipe2vec_investigation.ipynb#X45sZmlsZQ%3D%3D?line=19'>20</a>     losses[(alpha, num_epochs)] = [1,2,3,4]
#
# File ~/diss/recipe_rec/recommender_system.py:21, in build_timer.<locals>.inner(self, *args, **kwargs)
#      17 def inner(self, *args, **kwargs):
#      19     start = time.time_ns()
# ---> 21     f(self, *args, **kwargs)
#      23     end = time.time_ns()
#      25     self.build_time = end - start
#
# File ~/diss/recipe_rec/recipe2vec.py:62, in Recipe2Vec.__init__(self, index_path, model_path, num_epochs, alpha, vec_size, index_distance_metric, verbose)
#      59     logging.info("Training Word2Vec model.")
#      61 # need to build model and save vectors
# ---> 62 self.disk_data["model"]: str = self.train_model()
#      64 if verbose:
#      65     logging.info(
#      66         f"Trained Word2Vec model, stored at {self.disk_data['model']}"
#      67     )
#
# File ~/diss/recipe_rec/recipe2vec.py:114, in Recipe2Vec.train_model(self)
#     111 self.training_losses = []
#     113 # create model
# --> 114 self.model = Word2Vec(
#     115     recipes["RecipeIngredientParts"].values,
#     116     # use skipgram, not CBOW
#     117     sg=1,
#     118     vector_size=self.vec_size,
#     119     alpha=self.alpha,
#     120     # ensures rarely-occurring ingredients still are given a vector
#     121     min_count=1,
#     122     epochs=self.num_epochs,
#     123     compute_loss=True,
#     124     callbacks=[get_loss_callback(self)],
#     125 )
#     127 model_path = f"./data/recipe2vec_{self.execution_id}.model"
#     128 self.model.save(model_path)
#
# File ~/diss/.venv/lib/python3.8/site-packages/gensim/models/word2vec.py:430, in Word2Vec.__init__(self, sentences, corpus_file, vector_size, alpha, window, min_count, max_vocab_size, sample, seed, workers, min_alpha, sg, hs, negative, ns_exponent, cbow_mean, hashfxn, epochs, null_word, trim_rule, sorted_vocab, batch_words, compute_loss, callbacks, comment, max_final_vocab, shrink_windows)
#     428     self._check_corpus_sanity(corpus_iterable=corpus_iterable, corpus_file=corpus_file, passes=(epochs + 1))
#     429     self.build_vocab(corpus_iterable=corpus_iterable, corpus_file=corpus_file, trim_rule=trim_rule)
# --> 430     self.train(
#     431         corpus_iterable=corpus_iterable, corpus_file=corpus_file, total_examples=self.corpus_count,
#     432         total_words=self.corpus_total_words, epochs=self.epochs, start_alpha=self.alpha,
#     433         end_alpha=self.min_alpha, compute_loss=self.compute_loss, callbacks=callbacks)
#     434 else:
#     435     if trim_rule is not None:
#
# File ~/diss/.venv/lib/python3.8/site-packages/gensim/models/word2vec.py:1073, in Word2Vec.train(self, corpus_iterable, corpus_file, total_examples, total_words, epochs, start_alpha, end_alpha, word_count, queue_factor, report_delay, compute_loss, callbacks, **kwargs)
#    1070     callback.on_epoch_begin(self)
#    1072 if corpus_iterable is not None:
# -> 1073     trained_word_count_epoch, raw_word_count_epoch, job_tally_epoch = self._train_epoch(
#    1074         corpus_iterable, cur_epoch=cur_epoch, total_examples=total_examples,
#    1075         total_words=total_words, queue_factor=queue_factor, report_delay=report_delay,
#    1076         callbacks=callbacks, **kwargs)
#    1077 else:
#    1078     trained_word_count_epoch, raw_word_count_epoch, job_tally_epoch = self._train_epoch_corpusfile(
#    1079         corpus_file, cur_epoch=cur_epoch, total_examples=total_examples, total_words=total_words,
#    1080         callbacks=callbacks, **kwargs)
#
# File ~/diss/.venv/lib/python3.8/site-packages/gensim/models/word2vec.py:1434, in Word2Vec._train_epoch(self, data_iterable, cur_epoch, total_examples, total_words, queue_factor, report_delay, callbacks)
#    1431     thread.daemon = True  # make interrupting the process with ctrl+c easier
#    1432     thread.start()
# -> 1434 trained_word_count, raw_word_count, job_tally = self._log_epoch_progress(
#    1435     progress_queue, job_queue, cur_epoch=cur_epoch, total_examples=total_examples,
#    1436     total_words=total_words, report_delay=report_delay, is_corpus_file_mode=False,
#    1437 )
#    1439 return trained_word_count, raw_word_count, job_tally
#
# File ~/diss/.venv/lib/python3.8/site-packages/gensim/models/word2vec.py:1289, in Word2Vec._log_epoch_progress(self, progress_queue, job_queue, cur_epoch, total_examples, total_words, report_delay, is_corpus_file_mode)
#    1286 unfinished_worker_count = self.workers
#    1288 while unfinished_worker_count > 0:
# -> 1289     report = progress_queue.get()  # blocks if workers too slow
#    1290     if report is None:  # a thread reporting that it finished
#    1291         unfinished_worker_count -= 1
#
# File ~/anaconda3/lib/python3.8/queue.py:170, in Queue.get(self, block, timeout)
#     168 elif timeout is None:
#     169     while not self._qsize():
# --> 170         self.not_empty.wait()
#     171 elif timeout < 0:
#     172     raise ValueError("'timeout' must be a non-negative number")
#
# File ~/anaconda3/lib/python3.8/threading.py:302, in Condition.wait(self, timeout)
#     300 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301     if timeout is None:
# --> 302         waiter.acquire()
#     303         gotit = True
#     304     else:
#
# KeyboardInterrupt:

# %%
with open("training_losses.pkl", "wb") as f:

    pickle.dump(losses, f)

# %% [markdown]
# # Number of Ingredients Per Recipe

# %%
recipes["IngredientLen"] = recipes["RecipeIngredientParts"].str.len()

# %%
len(recipes[recipes["IngredientLen"] > 19])
# Out:
# 4721

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 4))
ax = sns.boxplot(recipes["IngredientLen"], fliersize=1.5, orient="h")

ax.set(
    xlabel="Number of Ingredients",
    title="Distribution of Number of Ingredients per Recipe",
)

plt.show()

# %% [markdown]
# Statistics:

# %%
recipes["IngredientLen"].describe()
# Out:
# count    511626.000000
# mean          8.054245
# std           3.847504
# min           2.000000
# 25%           5.000000
# 50%           8.000000
# 75%          10.000000
# max          44.000000
# Name: IngredientLen, dtype: float64

# %%
recipes["IngredientLen"].median()
# Out:
# 8.0

# %% [markdown]
# Number of training words:

# %%
recipes["IngredientLen"].sum()
# Out:
# 4120761

# %% [markdown]
# # Ingredient Count Distribution

# %%
ingredient_counts = {}

for recipe in recipes["RecipeIngredientParts"]:

    for ingredient in recipe:

        if ingredient in ingredient_counts:

            ingredient_counts[ingredient] += 1

        else:

            ingredient_counts[ingredient] = 1

# %%
len(ingredient_counts)
# Out:
# 7358

# %%
import numpy as np
import pandas as pd

# %%
ingredient_labels = ingredient_counts.keys()
ingredient_counts_y = np.array(list(ingredient_counts.values()))

# ingredient_counts_y = ingredient_counts_y[ingredient_counts_y < np.quantile(ingredient_counts_y, 1.0)]

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(25, 5))

sns.histplot(
    ingredient_counts_y[ingredient_counts_y > np.quantile(ingredient_counts_y, 0.2)],
    thresh=5,
)
plt.show()
sns.boxplot(ingredient_counts_y, orient="h")
plt.show()

display(pd.Series(ingredient_counts_y).describe())
# Out:
# count      7358.000000
# mean        560.038190
# std        4452.103373
# min           1.000000
# 25%           2.000000
# 50%          15.000000
# 75%         112.000000
# max      199717.000000
# dtype: float64

# %% [markdown]
# # Vector Size

# %%
import numpy as np

# %% [markdown]
# Create co-ocurrence matrix

# %%
ingredients = []
ingredient_indexes = {}

recipe_ingredients = recipes["RecipeIngredientParts"]

# get matrix size 
for recipe in recipe_ingredients:
    
    for ingredient in recipe:
        if ingredient not in ingredient_indexes.keys() and :
            
            ingredient_indexes[ingredient] = len(ingredients)
            ingredients.append(ingredient)

# %%
len(ingredients)
# Out:
# 3631

# %%
matrix = np.zeros((len(ingredients), len(ingredients)))

for recipe in recipe_ingredients:

    for ingredient in recipe:

        ingredient_index = ingredient_indexes[ingredient]

        for context_ingredient in recipe:

            context_index = ingredient_indexes[context_ingredient]

            matrix[ingredient_index][context_index] += 1
            matrix[context_index][ingredient_index] += 1

# %% [markdown]
# Create word-word cosine similarity matrix using co-ocurrence matrix

# %%
from scipy import spatial
import tqdm

similarity_matrix = np.zeros((len(ingredients), len(ingredients)))

# get each row's vector
for i in tqdm.tqdm(range(matrix.shape[0])):

    for j in range(matrix.shape[0]):

        if i == j:

            continue

        # compute similarity
        similarity = 1.0 - spatial.distance.cosine(matrix[i], matrix[j])

        similarity_matrix[i][j] = similarity
        similarity_matrix[j][i] = similarity
# Out:
# 100%|██████████| 3631/3631 [10:38<00:00,  5.69it/s]

# %% [markdown]
# Save the resulting matrix to disk for re-use:

# %%
import pickle

with open("similarity_matrix_trimmed.npy", "wb") as f:
    np.save(f, similarity_matrix, allow_pickle=True)

# %%
import tqdm.notebook as tqdm

# %%
import numpy as np

with open("similarity_matrix.npy", "rb") as f:
    similarity_matrix = np.load(f)

# %% [markdown]
# For each value in the similarity matrix:

# %%
import networkx as nx
from networkx.algorithms import approximation


def lambda_lookup_func(i):

    if i == 3 or i == 4:
        return 6
    elif i == 5:
        return 10
    elif i == 6:
        return 16
    elif i >= 7 and i <= 13:
        return 28
    elif i == 14:
        return 30
    elif i == 15:
        return 36
    elif i == 16:
        return 42
    elif i == 17:
        return 51
    elif i == 18:
        return 61
    elif i == 19:
        return 76
    elif i == 20:
        return 96
    elif i == 21:
        return 126
    elif i == 22:
        return 176
    elif i >= 23 and i <= 41:
        return 276
    elif i == 42:
        return 288
    elif i == 43:
        return 344


lambda_lookup = {lambda_lookup_func(i) for i in range(3, 44)}

# %%
# build graph
G = nx.Graph()

for i in range(similarity_matrix.shape[0]):
    G.add_node(i)

# %%
# get unique similarity values from the similarity matrix
unique_similarities = np.unique(similarity_matrix)

# %%
lambdas = []

for val in tqdm.tqdm(unique_similarities, desc="outer", position=0):

    # for each cell in the similarity matrix
    for i in tqdm.tqdm(range(similarity_matrix.shape[0]), desc="inner", position=1):

        for j in range(i + 1):

            if similarity_matrix[i][j] == val:

                G.add_edge(i, j)

    max_clique = approximation.max_clique(G)

    print("got max clique")
    max_clique_size = len(max_clique)

    lambda_k = lambda_lookup[max_clique_size]

    lambdas.append(lambda_k)

    G.clear_edges()
# Out:
# outer:   0%|          | 0/6586847 [00:00<?, ?it/s]
# inner:   0%|          | 0/3631 [00:00<?, ?it/s]
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
