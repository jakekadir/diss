# %% [markdown]
# Import recommendation classes:

# %%
from recipe2vec import Recipe2Vec
from sbert_embeddings import SBERTRecommender

DATASET_PATH = "../data/recipes.csv"
EXECUTION_ID = "trial_30_03"
# Out:
# 2023-03-30 17:07:47.047800: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-30 17:07:48.214286: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-03-30 17:07:48.214484: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-03-30 17:07:48.214497: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# Establish query to apply to all systems:

# %%
ingredients = ["onion", "pasta", "beef"]

# %% [markdown]
# # SBERT Recommender

# %%
bertender = SBERTRecommender(dataset_path=DATASET_PATH,
                             col_to_embed="RecipeIngredientParts",
                             execution_id=EXECUTION_ID)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/jake/diss/recipe_rec/explorer.ipynb Cell 6 in 1
# ----> <a href='vscode-notebook-cell:/home/jake/diss/recipe_rec/explorer.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> bertender = SBERTRecommender(dataset_path=DATASET_PATH,
#       <a href='vscode-notebook-cell:/home/jake/diss/recipe_rec/explorer.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a>                              col_to_embed="RecipeIngredientParts",
#       <a href='vscode-notebook-cell:/home/jake/diss/recipe_rec/explorer.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a>                              execution_id=EXECUTION_ID)
#
# File ~/diss/recipe_rec/sbert_embeddings.py:19, in SBERTRecommender.__init__(self, dataset_path, col_to_embed, execution_id)
#      13 def __init__(self,
#      14              dataset_path: Path,
#      15              col_to_embed: str,
#      16              execution_id: str):
#      17     super().__init__("SBERT", "", 384)
# ---> 19     self.generate_sbert_index(dataset_path,
#      20                               col_to_embed,
#      21                               execution_id)
#
# File ~/diss/recipe_rec/sbert_embeddings.py:68, in SBERTRecommender.generate_sbert_index(self, dataset_path, col_to_embed, execution_id)
#      65 out_path = pathlib.Path(f"sbert_{execution_id}.ann")
#      67 index.build(10)
# ---> 68 index.save(out_path)
#      70 return out_path
#
# TypeError: argument 1 must be str, not PosixPath

# %% [markdown]
# # Recipe2Vec

# %%
recipe2vec = Recipe2Vec(dataset_path=DATASET_PATH,verbose=False,execution_id=EXECUTION_ID)
# Out:
# INFO - 16:59:18: collecting all words and their counts
# INFO - 16:59:18: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - 16:59:18: PROGRESS: at sentence #10000, processed 79061 words, keeping 2764 word types
# INFO - 16:59:18: PROGRESS: at sentence #20000, processed 160340 words, keeping 3498 word types
# INFO - 16:59:18: PROGRESS: at sentence #30000, processed 240387 words, keeping 3881 word types
# INFO - 16:59:18: PROGRESS: at sentence #40000, processed 320440 words, keeping 4198 word types
# INFO - 16:59:18: PROGRESS: at sentence #50000, processed 398795 words, keeping 4418 word types
# INFO - 16:59:18: PROGRESS: at sentence #60000, processed 479639 words, keeping 4632 word types
# INFO - 16:59:18: PROGRESS: at sentence #70000, processed 563312 words, keeping 4809 word types
# INFO - 16:59:18: collected 4884 word types from a corpus of 586107 raw words and 72504 sentences
# INFO - 16:59:18: Creating a fresh vocabulary
# INFO - 16:59:18: Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 4884 unique words (100.00% of original 4884, drops 0)', 'datetime': '2023-03-30T16:59:18.544934', 'gensim': '4.3.1', 'python': '3.8.3 (default, Jul  2 2020, 16:21:59) \n[GCC 7.3.0]', 'platform': 'Linux-5.15.0-67-generic-x86_64-with-glibc2.10', 'event': 'prepare_vocab'}
# INFO - 16:59:18: Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 586107 word corpus (100.00% of original 586107, drops 0)', 'datetime': '2023-03-30T16:59:18.546217', 'gensim': '4.3.1', 'python': '3.8.3 (default, Jul  2 2020, 16:21:59) \n[GCC 7.3.0]', 'platform': 'Linux-5.15.0-67-generic-x86_64-with-glibc2.10', 'event': 'prepare_vocab'}
# INFO - 16:59:18: deleting the raw counts dictionary of 4884 items
# INFO - 16:59:18: sample=0.001 downsamples 68 most-common words
# INFO - 16:59:18: Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 405286.6266624567 word corpus (69.1%% of prior 586107)', 'datetime': '2023-03-30T16:59:18.599549', 'gensim': '4.3.1', 'python': '3.8.3 (default, Jul  2 2020, 16:21:59) \n[GCC 7.3.0]', 'platform': 'Linux-5.15.0-67-generic-x86_64-with-glibc2.10', 'event': 'prepare_vocab'}
# INFO - 16:59:18: estimated required memory for 4884 words and 100 dimensions: 6349200 bytes
# INFO - 16:59:18: resetting layer weights
# INFO - 16:59:18: Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-03-30T16:59:18.672139', 'gensim': '4.3.1', 'python': '3.8.3 (default, Jul  2 2020, 16:21:59) \n[GCC 7.3.0]', 'platform': 'Linux-5.15.0-67-generic-x86_64-with-glibc2.10', 'event': 'build_vocab'}
# INFO - 16:59:18: Word2Vec lifecycle event {'msg': 'training model with 3 workers on 4884 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2023-03-30T16:59:18.672880', 'gensim': '4.3.1', 'python': '3.8.3 (default, Jul  2 2020, 16:21:59) \n[GCC 7.3.0]', 'platform': 'Linux-5.15.0-67-generic-x86_64-with-glibc2.10', 'event': 'train'}
# INFO - 16:59:19: EPOCH 0: training on 586107 raw words (405070 effective words) took 0.7s, 600149 effective words/s
# INFO - 16:59:20: EPOCH 1: training on 586107 raw words (405016 effective words) took 0.7s, 620423 effective words/s
# INFO - 16:59:20: EPOCH 2: training on 586107 raw words (404705 effective words) took 0.7s, 588866 effective words/s
# INFO - 16:59:21: EPOCH 3: training on 586107 raw words (405351 effective words) took 0.8s, 505006 effective words/s
# INFO - 16:59:22: EPOCH 4: training on 586107 raw words (405065 effective words) took 0.6s, 644710 effective words/s
# INFO - 16:59:22: EPOCH 5: training on 586107 raw words (405096 effective words) took 0.6s, 624304 effective words/s
# INFO - 16:59:23: EPOCH 6: training on 586107 raw words (405327 effective words) took 0.7s, 603364 effective words/s
# INFO - 16:59:24: EPOCH 7: training on 586107 raw words (405030 effective words) took 0.8s, 536983 effective words/s
# INFO - 16:59:24: EPOCH 8: training on 586107 raw words (405670 effective words) took 0.7s, 593736 effective words/s
# INFO - 16:59:25: EPOCH 9: training on 586107 raw words (405183 effective words) took 0.8s, 505150 effective words/s
# INFO - 16:59:26: EPOCH 10: training on 586107 raw words (405578 effective words) took 0.8s, 492040 effective words/s
# INFO - 16:59:27: EPOCH 11: training on 586107 raw words (405099 effective words) took 0.7s, 587250 effective words/s
# INFO - 16:59:28: EPOCH 12: training on 586107 raw words (405209 effective words) took 0.8s, 534698 effective words/s
# INFO - 16:59:28: EPOCH 13: training on 586107 raw words (405113 effective words) took 0.7s, 594231 effective words/s
# INFO - 16:59:29: EPOCH 14: training on 586107 raw words (404926 effective words) took 0.7s, 607522 effective words/s
# INFO - 16:59:30: EPOCH 15: training on 586107 raw words (404811 effective words) took 0.7s, 608417 effective words/s
# INFO - 16:59:30: EPOCH 16: training on 586107 raw words (405172 effective words) took 0.6s, 675712 effective words/s
# INFO - 16:59:31: EPOCH 17: training on 586107 raw words (405068 effective words) took 0.7s, 620370 effective words/s
# INFO - 16:59:32: EPOCH 18: training on 586107 raw words (405538 effective words) took 0.7s, 561894 effective words/s
# INFO - 16:59:32: EPOCH 19: training on 586107 raw words (405514 effective words) took 0.9s, 474441 effective words/s
# INFO - 16:59:33: EPOCH 20: training on 586107 raw words (405277 effective words) took 0.7s, 555249 effective words/s
# INFO - 16:59:34: EPOCH 21: training on 586107 raw words (405851 effective words) took 0.7s, 589727 effective words/s
# INFO - 16:59:35: EPOCH 22: training on 586107 raw words (405766 effective words) took 0.8s, 522669 effective words/s
# INFO - 16:59:35: EPOCH 23: training on 586107 raw words (405336 effective words) took 0.8s, 536041 effective words/s
# INFO - 16:59:36: EPOCH 24: training on 586107 raw words (405084 effective words) took 0.8s, 482465 effective words/s
# INFO - 16:59:37: EPOCH 25: training on 586107 raw words (405065 effective words) took 0.8s, 511346 effective words/s
# INFO - 16:59:38: EPOCH 26: training on 586107 raw words (405332 effective words) took 1.0s, 405415 effective words/s
# INFO - 16:59:39: EPOCH 27: training on 586107 raw words (405431 effective words) took 0.8s, 515232 effective words/s
# INFO - 16:59:40: EPOCH 28: training on 586107 raw words (405417 effective words) took 0.8s, 536773 effective words/s
# INFO - 16:59:40: EPOCH 29: training on 586107 raw words (404929 effective words) took 0.7s, 546407 effective words/s
# INFO - 16:59:40: Word2Vec lifecycle event {'msg': 'training on 17583210 raw words (12157029 effective words) took 22.3s, 546287 effective words/s', 'datetime': '2023-03-30T16:59:40.927406', 'gensim': '4.3.1', 'python': '3.8.3 (default, Jul  2 2020, 16:21:59) \n[GCC 7.3.0]', 'platform': 'Linux-5.15.0-67-generic-x86_64-with-glibc2.10', 'event': 'train'}
# INFO - 16:59:40: Word2Vec lifecycle event {'params': 'Word2Vec<vocab=4884, vector_size=100, alpha=0.025>', 'datetime': '2023-03-30T16:59:40.927969', 'gensim': '4.3.1', 'python': '3.8.3 (default, Jul  2 2020, 16:21:59) \n[GCC 7.3.0]', 'platform': 'Linux-5.15.0-67-generic-x86_64-with-glibc2.10', 'event': 'created'}

# %%
recipe2vec.get_recommendations(ingredients, 10)
# Out:
# [23966, 15382, 54736, 60801, 52643, 54220, 46310, 32208, 63787, 45211]
#        RecipeId                                               Name  AuthorId  \
# 23966    148251                                     Beef Caldereta    263275
# 15382    100662                       Tasty Meat Sauce for Lasagna    125109
# 54736    354769                               Schnitzel from Drnis    389242
# 60801    408521                                   Paprika Goulasch   1518512
# 52643    336246                           Guinness Irish Beef Stew   1014941
# 54220    350281                                  One-Pot Spaghetti     53959
# 46310    288850    Traditional Iraqi 'casserole'- Tepsi Baytinijan    510313
# 32208    199999                            Old-Fashioned Beef Stew    269521
# 63787    439057  Wicklewoodwench&rsquo;s Shepherd&rsquo;s Pie W...   1308592
# 45211    281859          Hot Sandwich With Meat and Mushroom Sauce    383346
#
#             AuthorName CookTime PrepTime TotalTime         DatePublished  \
# 23966   George Clement    PT45M    PT20M    PT1H5M  2005-12-14T10:34:00Z
# 15382          atm1970     PT3H    PT30M   PT3H30M  2004-09-27T20:00:00Z
# 54736            nitko     PT2H    PT20M   PT2H20M  2009-02-09T01:11:00Z
# 60801  Jana Steinhagen  PT1H45M    PT20M    PT2H5M  2010-01-15T10:41:00Z
# 52643       Bigmama 24     PT1H    PT20M   PT1H20M  2008-11-10T23:19:00Z
# 54220   looneytunesfan    PT30M    PT10M     PT40M  2009-01-18T01:18:00Z
# 46310         Um Safia  PT1H10M    PT20M   PT1H30M  2008-02-27T00:12:00Z
# 32208     Galley Wench    PT40M    PT15M     PT55M  2006-12-10T13:11:00Z
# 63787  WicklewoodWench    PT45M    PT15M      PT1H  2010-10-09T04:58:00Z
# 45211         Boomette    PT20M    PT10M     PT30M  2008-01-28T00:17:00Z
#
#                                              Description  \
# 23966  This is a tasty dish from the Philippines.  I ...
# 15382  Looking to use up some stuff in my freezer, I ...
# 54736  This is one of the many ways of preparing beef...
# 60801  A hearty beef stew with red peppers, flavoured...
# 52643  Make and share this Guinness Irish Beef Stew r...
# 54220  Make and share this One-Pot Spaghetti recipe f...
# 46310  In Iraq Tepsi Baytinijan is a very famous dish...
# 32208  The original recipe comes from my Pressured Co...
# 63787  I love a classic shepherd&rsquo;s pie, but I a...
# 45211  A recipe from the issue of November 2005 of Co...
#
#                                                   Images  ...  \
# 23966  (https://img.sndimg.com/food/image/upload/w_55...  ...
# 15382  (https://img.sndimg.com/food/image/upload/w_55...  ...
# 54736  (https://img.sndimg.com/food/image/upload/w_55...  ...
# 60801  (https://img.sndimg.com/food/image/upload/w_55...  ...
# 52643  (https://img.sndimg.com/food/image/upload/w_55...  ...
# 54220  (https://img.sndimg.com/food/image/upload/w_55...  ...
# 46310  (https://img.sndimg.com/food/image/upload/w_55...  ...
# 32208  (https://img.sndimg.com/food/image/upload/w_55...  ...
# 63787  (https://img.sndimg.com/food/image/upload/w_55...  ...
# 45211  (https://img.sndimg.com/food/image/upload/w_55...  ...
#
#       SaturatedFatContent CholesterolContent SodiumContent  \
# 23966                47.7              192.4         641.8
# 15382                22.8              131.2        1747.4
# 54736                18.7               50.9        1912.3
# 60801                 8.7               27.3          25.2
# 52643                47.8              155.7        1630.0
# 54220                 4.8               44.1         805.7
# 46310                 5.1               56.6         168.4
# 32208                84.5              280.4         596.3
# 63787                16.0              101.5         572.2
# 45211                 8.2               62.6        1004.7
#
#       CarbohydrateContent  FiberContent  SugarContent  ProteinContent  \
# 23966                37.3           5.3          11.7            22.8
# 15382                27.2           6.6          15.6            39.3
# 54736                19.4           3.7           8.9             8.5
# 60801                14.2           3.2           6.3             4.3
# 52643               103.4          10.4          12.2            27.7
# 54220                43.5           3.7           7.9            23.4
# 46310                45.4          13.9          12.8            22.4
# 32208                98.2          13.8          10.9            34.8
# 63787                44.6           5.6           7.1            27.4
# 45211                53.4           5.7          14.5            30.5
#
#        RecipeServings  RecipeYield  \
# 23966             NaN          NaN
# 15382             NaN          NaN
# 54736             3.0   3 portions
# 60801             4.0          NaN
# 52643             NaN          NaN
# 54220             4.0          NaN
# 46310             NaN          NaN
# 32208             4.0          NaN
# 63787             6.0          NaN
# 45211             4.0          NaN
#
#                                       RecipeInstructions
# 23966  (Boil the beef until tender, in the water to m...
# 15382  (Remove sausage from casings., In a large pot,...
# 54736  (Sauté onion on olive oil until becomes transl...
# 60801  (Season the beef in Salt, Pepper and Paprika.,...
# 52643  (Heat olive oil in heavy large pot over medium...
# 54220  (In a large saucepan cook the ground beef, fre...
# 46310  (Peel the eggplant in wide stripes and remove ...
# 32208  (To flour mix in salt and pepper., Dredge beef...
# 63787  (Over a high heat, in a large pan of salted wa...
# 45211  (In a large skillet, heat oil at medium-high h...
#
# [10 rows x 28 columns]
