# %% [markdown]
# Import recommendation classes:

# %%
from recipe2vec import Recipe2Vec
from sbert_embeddings import SBERTRecommender

DATASET_PATH = "../data/recipes.csv"
EXECUTION_ID = "trial_30_03"
# Out:
# 2023-03-31 13:18:58.438791: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-31 13:18:59.978816: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-03-31 13:18:59.978926: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# ...

# %% [markdown]
# Establish query to apply to all systems:

# %%
ingredients = ["onion", "pasta", "beef"]

# %% [markdown]
# # SBERT Recommender

# %%
bertender = SBERTRecommender(dataset_path=DATASET_PATH,
                             col_to_embed="RecipeIngredientParts",
                             execution_id=EXECUTION_ID)

# %%
bertender.get_recommendations(ingredients, 10)
# Out:
# [2459, 7048, 8517, 8803, 11480, 11827, 22535, 23041, 51383, 53449]
#        RecipeId                               Name  AuthorId  \
# 2459      17990                          Beef Tips     26041
# 7048      47539         Meat and Potato Chili Soup     56112
# 8517      57030                   Wastebasket Soup      8688
# 8803      58901  Old-Fashioned Vegetable Beef Soup     63128
# 11480     76839            Brothy Beef Noodle Soup      1533
# 11827     79082        Beef Stroganoff - Crock Pot    104610
# 22535    139687                Savory Beef Paprika    103876
# 23041    142433                         Beef Pilau    226863
# 51383    325265      Creamy Celery Beef Stroganoff    513784
# 53449    343667        Slow Cooker Beef Stroganoff    846154
#
#                 AuthorName CookTime PrepTime TotalTime         DatePublished  \
# 2459              Dana-MMH     PT2H    PT15M   PT2H15M  2002-01-24T18:26:00Z
# ...

# %% [markdown]
# # Recipe2Vec

# %%
recipe2vec = Recipe2Vec(dataset_path=DATASET_PATH,verbose=False,execution_id=EXECUTION_ID)

# %%
recipe2vec.get_recommendations(ingredients, 10)
# Out:
# [54220, 7084, 45211, 38818, 142, 12721, 15358, 64146, 33804, 20653]
#        RecipeId                                               Name  AuthorId  \
# 54220    350281                                  One-Pot Spaghetti     53959
# 7084      47719                          Ground Beef Chinese Style     20480
# 45211    281859          Hot Sandwich With Meat and Mushroom Sauce    383346
# 38818    238734                                        Cottage Pie    287420
# 142        1356  Ground Beef Stuffed Green Bell Peppers With Ch...      1555
# 12721     85128                    Spicy Homemade Hamburger Helper     50441
# 15358    100517            Rigatoni in Zesty Tomato and Meat Sauce    164221
# 64146    442712                 Salisbury Steak and Mushroom Gravy   1726971
# 33804    209470                                   Ground Beef Soup    304635
# 20653    130118                               Oven Baked Schnitzel     11297
#
# ...
